# %% [markdown]
# <a href="https://colab.research.google.com/github/therealdj97/MachineLearning/blob/main/day2/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Real-world datasets often contain features that are varying in degrees of magnitude, range and units. Therefore, in order for machine learning models to interpret these features on the same scale, we need to perform feature scaling.
#
# # min max scaller is used for skewed data also when your dataset has high veriance

# %% [markdown]
# The machine learning algorithm works on numbers and does not know what that number represents. A weight of 10 grams and a price of 10 dollars represents completely two different things — which is a no brainer for humans, but for a model as a feature, it treats both as same.

# %% [markdown]
# there are 2 methods two achieve featue scaling
# 1.   Min max scaller (0 to 1)
# 2.   Standard Scaler (-1 to 1)
#
# if we have -ve values in dataset and we apply min max scaller we will get same result as of std scaller

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# min max scaller formula
# ![image.png](data:image/png;base64,...)

# %%
# Min max scaller
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df = pd.DataFrame({'WEIGHT': [15, 18, 12,10],
                   'PRICE': [1,3,2,5]},
                   index = ['Orange','Apple','Banana','Grape'])
df1 = pd.DataFrame(scaler.fit_transform(df),
                   columns=['WEIGHT','PRICE'],
                   index = ['Orange','Apple','Banana','Grape'])

ax = df.plot.scatter(x='WEIGHT', y='PRICE',color=['red','green','blue','yellow'], 
                     marker = '*',s=80, label='BREFORE SCALING');
df1.plot.scatter(x='WEIGHT', y='PRICE', color=['red','green','blue','yellow'],
                 marker = 'o',s=60,label='AFTER SCALING', ax = ax);
plt.axhline(0, color='red',alpha=0.2)
plt.axvline(0, color='red',alpha=0.2);

# %%
# Min max scaller
df=pd.read_csv("Iris.csv")
df.drop("Species",axis=1,inplace=True)
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
df1=pd.DataFrame(scaler.fit_transform(df),columns=['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'])
ax=df.plot.scatter(x="SepalLengthCm",y="SepalWidthCm",marker="*",label="Before-Scaling",color="red")
df1.plot.scatter(x="SepalLengthCm",y="SepalWidthCm",marker="+",label="After-Scaling",ax=ax)
plt.axhline(0, color='red',alpha=0.2)
plt.axvline(0, color='red',alpha=0.2);
plt.show()

# %%
# std scaller
from sklearn.preprocessing import StandardScaler
standardscaler=StandardScaler()
df = pd.DataFrame({'WEIGHT': [15, 18, 12,10],
                   'PRICE': [1,3,2,5]},
                   index = ['Orange','Apple','Banana','Grape'])
df1=pd.DataFrame(scaler.fit_transform(df),columns=['WEIGHT', 'PRICE'],index = ['Orange','Apple','Banana','Grape'])

ax=df.plot.scatter(x="WEIGHT",y="PRICE",marker="*",s=60,label="Before Scaling",color="red")
df1.plot.scatter(x="WEIGHT",y="PRICE",marker="*",s=60,label="After Scaling",ax=ax)
plt.axhline(0, color='red',alpha=0.2)
plt.axvline(0, color='red',alpha=0.2);

# %%
df=pd.read_csv("Iris.csv")
df.drop("Species",axis=1,inplace=True)
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
df1=pd.DataFrame(scaler.fit_transform(df),columns=['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'])
ax=df.plot.scatter(x="SepalLengthCm",y="SepalWidthCm",marker="*",label="Before-Scaling",color="red")
df1.plot.scatter(x="SepalLengthCm",y="SepalWidthCm",marker="+",label="After-Scaling",ax=ax)
plt.axhline(0, color='red',alpha=0.2)
plt.axvline(0, color='red',alpha=0.2);
plt.show()

# %% [markdown]
# Min -Max	| Standard |	Max Abs |	Robust
#
# 0-1(can take -ve)	| minus 1 to plus 1 |	0 to 1 | 	Outliers

# %% [markdown]
# used to calc similarity between data points
# can be used in both supervised and unsupervised learning
#
# 1.   Euclidian dist
# 2.   Manhatten dist
# 3.   Minkowski dist
# 4.   Hamming dist

# %% [markdown]
# Euclidian dist. represents shortest dist between 2 points |
# can be used for k-means

# %%
from scipy.spatial import distance
import math

p1 =(1,2,3)
p2 = (4,5,6)

math.dist(p1,p2)
# Out:
# 5.196152422706632

# %% [markdown]
# Manhatten dist is sum of absolute dist between 2 points across all dimentions
# dist = |x1-x2| + |y1-y2|

# %%
def get_manhatten_dist(p,q):
  """
    will give manhatten dist between 2 points assuming they are of same dim
  """
  dist=0
  for p_i,q_i in zip(p,q):
    dist += abs(p_i - q_i)
  return dist

# %%
a=(1,1)
b=(4,3)
# dist between a and b
d= get_manhatten_dist(a,b)
print(d)
# Out:
# 5

# %% [markdown]
# #Label encoding of datasets
# Dealing with datasets containing multiple labels in 1 or more than 1 column
# labels can be in form of words or numbers
# training data is often labeled in words
# label encoding refers to converting labels into numeric form

# %%
Height:  Tall, Medium, Short
Height:0,1,2
# Out:
#   File "<ipython-input-18-37be89bb1df5>", line 1
#     Height:  Tall, Medium, short
#                  ^
# SyntaxError: invalid syntax

# %%
df=pd.read_csv("Iris.csv")
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
# import label encoder
from sklearn import preprocessing

label_encoder = preprocessor.LabelEncoder()

df['Species'] = label_encoder.fot_transform
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-a49578481332> in <module>
#       2 from sklearn import preprocessing
#       3
# ----> 4 label_encoder = preprocessor.LabelEncoder()
#       5
#       6 df['Species'] = label_encoder.fot_transform
#
# NameError: name 'preprocessor' is not defined

# %% [markdown]
# One hot Label Encoding	One-hot Encoding
# 1. The categorical values are labeled into numeric values by assigning each category to a number	1. A column with categorical values is split into multiple columns.
# 2. Different columns are not added. Rather different categories are converted into numeric values. So fewer computations.	2. It will add more columns and will be computationally heavy
# 3. Unique information is there	3. Redundant information is there
# 4. Different integers are used to represent data	4. Only 0 and 1 are used to represent data

# %% [markdown]
# Principle componenet analysis
# # it is widely used tool fopr EDA in ML for predictive models
# PCA is an unsupervised statastical technique used to examine interrelations among set of variables
# also known as general factor analysis where regression determines a line of best fit

# %%
from sklearn.datasets import load_breast_cancer
cancer = load_breast_cancer()
df = pd.DataFrame(cancer['data'], columns = cancer['feature_names'])
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()

# %%
scalar.fit(df)
scaled_data = scalar.transform(df)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components = 2)
pca.fit(scaled_data)
x_pca = pca.transform(scaled_data)
x_pca.shape
#transformed data into std scaler furthermore  transformed it into pca scaller
# Out:
# (569, 2)

# %%
plt.figure(figsize = (8,6))
plt.scatter(x_pca[:,0], x_pca[:,1], c= cancer['target'],cmap="plasma")
plt.xlabel("First PC")
plt.ylabel("Second PC")
# Out:
# Text(0, 0.5, 'Second PC')

# %%
pca.components_
# Out:
# array([[ 0.21890244,  0.10372458,  0.22753729,  0.22099499,  0.14258969,
#          0.23928535,  0.25840048,  0.26085376,  0.13816696,  0.06436335,
#          0.20597878,  0.01742803,  0.21132592,  0.20286964,  0.01453145,
#          0.17039345,  0.15358979,  0.1834174 ,  0.04249842,  0.10256832,
#          0.22799663,  0.10446933,  0.23663968,  0.22487053,  0.12795256,
#          0.21009588,  0.22876753,  0.25088597,  0.12290456,  0.13178394],
#        [-0.23385713, -0.05970609, -0.21518136, -0.23107671,  0.18611302,
#          0.15189161,  0.06016536, -0.0347675 ,  0.19034877,  0.36657547,
#         -0.10555215,  0.08997968, -0.08945723, -0.15229263,  0.20443045,
#          0.2327159 ,  0.19720728,  0.13032156,  0.183848  ,  0.28009203,
#         -0.21986638, -0.0454673 , -0.19987843, -0.21935186,  0.17230435,
#          0.14359317,  0.09796411, -0.00825724,  0.14188335,  0.27533947]])

# %%
df_comp =pd.DataFrame(pca.components_, columns=cancer['feature_names'])
plt.figure(figsize =(14,6))
sns.heatmap(df_comp)

# %% [markdown]
# # Abelas chart
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Decision Tree Classifier

# %%
df1=pd.read_csv("salaries.csv")

# %%
df1
# Out:
#        company                  job     degree  salary_more_then_100k
# 0       google      sales executive  bachelors                      0
# 1       google      sales executive    masters                      0
# 2       google     business manager  bachelors                      1
# 3       google     business manager    masters                      1
# 4       google  computer programmer  bachelors                      0
# 5       google  computer programmer    masters                      1
# 6   abc pharma      sales executive    masters                      0
# 7   abc pharma  computer programmer  bachelors                      0
# 8   abc pharma     business manager  bachelors                      0
# 9   abc pharma     business manager    masters                      1
# 10    facebook      sales executive  bachelors                      1
# 11    facebook      sales executive    masters                      1
# ...

# %%
inputs = df1.drop('salary_more_then_100k',axis='columns')

# %%
target = df1['salary_more_then_100k']

# %%
from sklearn.preprocessing import LabelEncoder
le_company = LabelEncoder()
le_job = LabelEncoder()
le_degree = LabelEncoder()

# %%
inputs['compnay_n'] = le_company.fit_transform(inputs['company'])
inputs['job_n'] = le_job.fit_transform(inputs['job'])
inputs['degree_n'] = le_degree.fit_transform(inputs['degree'])

# %%
inputs
# Out:
#        company                  job     degree  compnay_n  job_n  degree_n
# 0       google      sales executive  bachelors          2      2         0
# 1       google      sales executive    masters          2      2         1
# 2       google     business manager  bachelors          2      0         0
# 3       google     business manager    masters          2      0         1
# 4       google  computer programmer  bachelors          2      1         0
# 5       google  computer programmer    masters          2      1         1
# 6   abc pharma      sales executive    masters          0      2         1
# 7   abc pharma  computer programmer  bachelors          0      1         0
# 8   abc pharma     business manager  bachelors          0      0         0
# 9   abc pharma     business manager    masters          0      0         1
# 10    facebook      sales executive  bachelors          1      2         0
# ...

# %%
inputs_n = inputs.drop(['company','job','degree'],axis='columns')

# %%
inputs_n
# Out:
#     compnay_n  job_n  degree_n
# 0           2      2         0
# 1           2      2         1
# 2           2      0         0
# 3           2      0         1
# 4           2      1         0
# 5           2      1         1
# 6           0      2         1
# 7           0      1         0
# 8           0      0         0
# 9           0      0         1
# 10          1      2         0
# 11          1      2         1
# 12          1      0         0
# 13          1      0         1
# 14          1      1         0
# 15          1      1         1

# %%
target
# Out:
# 0     0
# 1     0
# 2     1
# 3     1
# 4     0
# 5     1
# 6     0
# 7     0
# 8     0
# 9     1
# 10    1
# 11    1
# 12    1
# 13    1
# 14    1
# 15    1
# Name: salary_more_then_100k, dtype: int64

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()

# %%
model.fit(inputs_n,target)
# Out:
# DecisionTreeClassifier()

# %%
model.score(inputs_n,target)
# Out:
# 1.0

# %% [markdown]
# is salery of google cs engineer bachlors greee > 100k?

# %%
model.predict([[2,1,0]])
# Out:
# array([0])
