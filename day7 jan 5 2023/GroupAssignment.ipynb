# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplot inline
# Out:
# UsageError: Line magic function `%matplot` not found.

# %%
df = pd.read_csv("/content/healthcare-dataset-stroke-data.csv")
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
plt.xlabel('age', color="white")
plt.ylabel('hypertension', color = "white")
plt.scatter(df.age, df.hypertension)
plt.show()

# %%
plt.xlabel('age', color="white")
plt.ylabel('heart_disease', color = "white")
plt.scatter(df.age, df.hypertension)
plt.show()

# %%
n_df= df.drop('bmi', axis='columns')
n_df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   smoking_status  stroke
# ...

# %%
n_df= n_df.drop('id', axis='columns')
n_df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1     Female  61.0             0              0          Yes  Self-employed
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 5105  Female  80.0             1              0          Yes        Private
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
# ...

# %%
n_df= n_df.drop('work_type', axis='columns')
n_df
# Out:
#       gender   age  hypertension  heart_disease Residence_type  \
# 0       Male  67.0             0              1          Urban
# 1     Female  61.0             0              0          Rural
# 2       Male  80.0             0              1          Rural
# 3     Female  49.0             0              0          Urban
# 4     Female  79.0             1              0          Rural
# ...      ...   ...           ...            ...            ...
# 5105  Female  80.0             1              0          Urban
# 5106  Female  81.0             0              0          Urban
# 5107  Female  35.0             0              0          Rural
# 5108    Male  51.0             0              0          Rural
# 5109  Female  44.0             0              0          Urban
#
#       avg_glucose_level   smoking_status  stroke
# 0                228.69  formerly smoked       1
# 1                202.21     never smoked       1
# 2                105.92     never smoked       1
# ...

# %%
n_df= n_df.drop('Residence_type', axis='columns')
n_df
# Out:
#       gender   age  hypertension  heart_disease  avg_glucose_level  \
# 0       Male  67.0             0              1             228.69
# 1     Female  61.0             0              0             202.21
# 2       Male  80.0             0              1             105.92
# 3     Female  49.0             0              0             171.23
# 4     Female  79.0             1              0             174.12
# ...      ...   ...           ...            ...                ...
# 5105  Female  80.0             1              0              83.75
# 5106  Female  81.0             0              0             125.20
# 5107  Female  35.0             0              0              82.99
# 5108    Male  51.0             0              0             166.29
# 5109  Female  44.0             0              0              85.28
#
#        smoking_status  stroke
# 0     formerly smoked       1
# 1        never smoked       1
# 2        never smoked       1
# 3              smokes       1
# ...

# %%
n_df= n_df.drop('gender', axis='columns')
n_df
# Out:
#        age  hypertension  heart_disease  avg_glucose_level   smoking_status  \
# 0     67.0             0              1             228.69  formerly smoked
# 1     61.0             0              0             202.21     never smoked
# 2     80.0             0              1             105.92     never smoked
# 3     49.0             0              0             171.23           smokes
# 4     79.0             1              0             174.12     never smoked
# ...    ...           ...            ...                ...              ...
# 5105  80.0             1              0              83.75     never smoked
# 5106  81.0             0              0             125.20     never smoked
# 5107  35.0             0              0              82.99     never smoked
# 5108  51.0             0              0             166.29  formerly smoked
# 5109  44.0             0              0              85.28          Unknown
#
#       stroke
# 0          1
# 1          1
# ...

# %%
inputs = df.drop("stroke", axis='columns')

# %%
target = df['stroke']

# %%
from sklearn import linear_model

# %%
hypertension=df.hypertension
hypertension
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 5105    1
# 5106    0
# 5107    0
# 5108    0
# 5109    0
# Name: hypertension, Length: 5110, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le_age = LabelEncoder()
le_hypertension = LabelEncoder()
le_heart_disease = LabelEncoder()
le_smoking_status = LabelEncoder()

# %%
inputs['age_n'] = le_age.fit_transform(inputs['age'])
inputs['hypertension_n'] = le_hypertension.fit_transform(inputs['hypertension'])
inputs['heart_disease_n'] = le_heart_disease.fit_transform(inputs['heart_disease'])
inputs['smoking_status_n'] = le_smoking_status.fit_transform(inputs['smoking_status'])

# %%
inputs
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
inputs_n = inputs.drop(['id','gender','age','hypertension','heart_disease','ever_married','work_type','Residence_type','avg_glucose_level','bmi','smoking_status'], axis='columns')

# %%
inputs_n
# Out:
#       age_n  hypertension_n  heart_disease_n  smoking_status_n
# 0        88               0                1                 1
# 1        82               0                0                 2
# 2       101               0                1                 2
# 3        70               0                0                 3
# 4       100               1                0                 2
# ...     ...             ...              ...               ...
# 5105    101               1                0                 2
# 5106    102               0                0                 2
# 5107     56               0                0                 2
# 5108     72               0                0                 1
# 5109     65               0                0                 0
#
# [5110 rows x 4 columns]

# %%
target
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 5105    0
# 5106    0
# 5107    0
# 5108    0
# 5109    0
# Name: stroke, Length: 5110, dtype: int64

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()

# %%
model.fit(inputs_n, target)
# Out:
# DecisionTreeClassifier()

# %%
model.score(inputs_n,target)
# Out:
# 0.9559686888454012

# %%
sns.pairplot()
