# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
# %matplotlib inline
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import plotly.express as px
import numpy as np
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df=pd.read_csv("CarPrice_Assignment.csv")
df.head(7)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
# 5       6          2                  audi fox      gas        std        two
# 6       7          1                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# ...

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df1=df.drop(['car_ID', 'symboling', 'CarName','doornumber','enginelocation','price'],axis=1)
df1.head()
# Out:
#   fueltype aspiration      carbody drivewheel  wheelbase  carlength  carwidth  \
# 0      gas        std  convertible        rwd       88.6      168.8      64.1
# 1      gas        std  convertible        rwd       88.6      168.8      64.1
# 2      gas        std    hatchback        rwd       94.5      171.2      65.5
# 3      gas        std        sedan        fwd       99.8      176.6      66.2
# 4      gas        std        sedan        4wd       99.4      176.6      66.4
#
#    carheight  curbweight enginetype cylindernumber  enginesize fuelsystem  \
# 0       48.8        2548       dohc           four         130       mpfi
# 1       48.8        2548       dohc           four         130       mpfi
# 2       52.4        2823       ohcv            six         152       mpfi
# 3       54.3        2337        ohc           four         109       mpfi
# 4       54.3        2824        ohc           five         136       mpfi
#
# ...

# %%
targets=df['price']

# %%
targets.head()
# Out:
# 0    13495.0
# 1    16500.0
# 2    16500.0
# 3    13950.0
# 4    17450.0
# Name: price, dtype: float64

# %%
df1
# Out:
#     fueltype aspiration      carbody drivewheel  wheelbase  carlength  \
# 0        gas        std  convertible        rwd       88.6      168.8
# 1        gas        std  convertible        rwd       88.6      168.8
# 2        gas        std    hatchback        rwd       94.5      171.2
# 3        gas        std        sedan        fwd       99.8      176.6
# 4        gas        std        sedan        4wd       99.4      176.6
# ..       ...        ...          ...        ...        ...        ...
# 200      gas        std        sedan        rwd      109.1      188.8
# 201      gas      turbo        sedan        rwd      109.1      188.8
# 202      gas        std        sedan        rwd      109.1      188.8
# 203   diesel      turbo        sedan        rwd      109.1      188.8
# 204      gas      turbo        sedan        rwd      109.1      188.8
#
#      carwidth  carheight  curbweight enginetype cylindernumber  enginesize  \
# ...

# %%
df1.columns
# Out:
# Index(['fueltype', 'aspiration', 'carbody', 'drivewheel', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg'],
#       dtype='object')

# %%
sns.relplot(x='enginesize',y='price',hue='cylindernumber',data=df1)

# %%
sns.lmplot(x='enginesize',y='price',data=df1)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

#fueltype	aspiration	carbody	drivewheel enginetype	cylindernumber fuelsystem

# %%
df1['fueltype_n'] = le.fit_transform(df1['fueltype'])
df1['aspiration_n'] = le.fit_transform(df1['aspiration'])
df1['carbody_n'] = le.fit_transform(df1['carbody'])
df1['drivewheel_n'] = le.fit_transform(df1['drivewheel'])
df1['enginetype_n'] = le.fit_transform(df1['enginetype'])
df1['cylindernumber_n'] = le.fit_transform(df1['cylindernumber'])
df1['fuelsystem_n'] = le.fit_transform(df1['fuelsystem'])
# df1['_n'] = le.fit_transform(df1[''])

df1.head()
# Out:
#   fueltype aspiration      carbody drivewheel  wheelbase  carlength  carwidth  \
# 0      gas        std  convertible        rwd       88.6      168.8      64.1
# 1      gas        std  convertible        rwd       88.6      168.8      64.1
# 2      gas        std    hatchback        rwd       94.5      171.2      65.5
# 3      gas        std        sedan        fwd       99.8      176.6      66.2
# 4      gas        std        sedan        4wd       99.4      176.6      66.4
#
#    carheight  curbweight enginetype  ... peakrpm  citympg highwaympg  \
# 0       48.8        2548       dohc  ...    5000       21         27
# 1       48.8        2548       dohc  ...    5000       21         27
# 2       52.4        2823       ohcv  ...    5000       19         26
# 3       54.3        2337        ohc  ...    5500       24         30
# 4       54.3        2824        ohc  ...    5500       18         22
#
#    fueltype_n  aspiration_n  carbody_n  drivewheel_n  enginetype_n  \
# ...

# %%
df1 = df1.drop(['fueltype','aspiration','carbody','drivewheel','enginetype','cylindernumber','fuelsystem'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-185-117d65e6dbab> in <module>
# ----> 1 df1 = df1.drop(['fueltype','aspiration','carbody','drivewheel','enginetype','cylindernumber','fuelsystem'],axis=1)
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
df1.head(1)
# Out:
#    wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# 0       88.6      168.8      64.1       48.8        2548         130
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0       3.47    2.68               9.0         111     5000       21
#
#    highwaympg  fueltype_n  aspiration_n  carbody_n  drivewheel_n  \
# 0          27           1             0          0             2
#
#    enginetype_n  cylindernumber_n  fuelsystem_n
# 0             0                 2             5

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df1, targets, test_size=0.2,random_state=1)

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(X_train,y_train)
reg.score(X_test,y_test)
# Out:
# 0.7789391527736729

# %%
reg.predict([[88.6,168.8,64.1,48.8,2548,130,3.47,2.68,9.0,111,5000,21,27,1,0,0,2,0,2,5]])
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning:
#
# X does not have valid feature names, but LinearRegression was fitted with feature names
# array([13945.60815809])
